# %% [markdown]
# <a href="https://colab.research.google.com/github/123chri/Machine-Learning-with-Python-Bootcamp/blob/main/Orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of addition

# %%
A=2
B=3
C=2+3
print(C)
# Out:
# 5

# %% [markdown]
# Example of string

# %%
Greetings= "Advice na, pror"
print (Greetings)
# Out:
# Advice na, pror
