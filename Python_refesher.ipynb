# %% [markdown]
# <a href="https://colab.research.google.com/github/123chri/Machine-Learning-with-Python-Bootcamp/blob/main/Python_refesher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
# Create a labeled storage basket and put a number inside
tomatoe_price = 150
pepper_price = 80

#Full the value out of the baskets
print(tomatoe_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Variables ML Anchor

# %%
#--- THE CLUES (Features grouped as X) ---
rainfall_mm = 45.2      # Clue 1
bags_available = 100    # Clue 2

#--- THE COAL  (Target labeled as y) ---
predicted_price = 3200  #What our AI calculates

print("Inputs (x):", rainfall_mm, "mm rain,", bags_available, "bags")
print("Output (y):", predicted_price, "LRD.")
# Out:
# Inputs (x): 45.2 mm rain, 100 bags
# Output (y): 3200 LRD.

# %% [markdown]
# Understanding Print Statement

# %%
Liberia = 1847
print(Liberia)  # Value will appear
print("Liberia") # Text will appear
# Out:
# 1847
# Liberia

# %% [markdown]
# Understanding Variables

# %%
plum = 50
del print  # Delete the overwritten 'print' variable
print(plum)
# Out:
# 50

# %%
plum = 50
print("plum previous price was:", plum)
plum = 80
print("plum new price is:", plum)
# Out:
# plum previous price was: 50
# plum new price is: 80

# %% [markdown]
# Data Types

# %%
quatity = 50
price = 150.50
item_name = "tomatoes"
stall_is_open = True

print(type(quatity))   # Corrected from 'quantity'
print(type(price))      #
print(type(item_name))  #
print(type(stall_is_open))  # Corrected from 'stall_is_open'
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Type Conversion

# %%
raw_input = "150"
price = int(raw_input)
print(price + 50)

total_cost = 304.5
message = "Your total is LRD" + str(total_cost)
print(message)
# Out:
# 200
# Your total is LRD304.5

# %% [markdown]
# Lists(Oridinary Scaffold)

# %%
goods = ["tomatoes", "peppers", "onions", "rice"]
print(goods)
print(goods[0])
print(goods[2])
# Out:
# ['tomatoes', 'peppers', 'onions', 'rice']
# tomatoes
# onions

# %%
print(goods[0])
# Out:
# tomatoes

# %%
print(goods[2])
# Out:
# onions

# %% [markdown]
# Lists (ML Anchor)

# %%
loose_list = [3100, 3200, 3150]
# ML-ready crate: double brackets [[]]
crate_matrix = [loose_list]

print("Rejected by AI:", loose_list)
print("Accepted by AI (Crate):", crate_matrix)
# Out:
# Rejected by AI: [3100, 3200, 3150]
# Accepted by AI (Crate): [[3100, 3200, 3150]]

# %% [markdown]
# F- Strings for clean reporting

# %%
model_accuracy = 0.9456
predicted_value = 3500

print(f"Ma Christiana, our market AI model is {model_accuracy:.1%} accurate.")
print(f"Predicted price for rice at Red Light is: {predicted_value} LRD.")
# Out:
# Ma Christiana, our market AI model is 94.6% accurate.
# Predicted price for rice at Red Light is: 3500 LRD.

# %%
model_accuracy = 0.9456
predicted_value = 3500

print(f"Ma Christiana, our market AI model is {model_accuracy:.2%} accurate.")
print(f"Predicted price for rice at Red Light is: {predicted_value} LRD.")
# Out:
# Ma Christiana, our market AI model is 94.56% accurate.
# Predicted price for rice at Red Light is: 3500 LRD.

# %% [markdown]
# Dictionaries (Ordinary Scaffold)

# %%
Stall_prices = {
    "tomatoes": 150,
    "peppers": 80,
    "onions": 60
}
print(Stall_prices["tomatoes"])
print(Stall_prices["onions"])
# Out:
# 150
# 60

# %%
menu={
    "potatoes green": 700,
    "beans": 300,
    "fried rice": 500,
}
print(menu["potatoes green"])
print(menu["beans"])
print(menu["fried rice"])
# Out:
# 700
# 300
# 500

# %% [markdown]
# Dictionaries (ML Anchor)

# %%
model_settings = {
    "learning_rate": 0.001,
    "algorithm": "Random Forest",
    "number_of_trees": 100
}
print(f"Initializing {model_settings['algorithm']} engine...")
print(f"Running with {model_settings['number_of_trees']} trees.")
# Out:
# Initializing Random Forest engine...
# Running with 100 trees.

# %% [markdown]
# Libraries (Importing Toolboxes)

# %%
import math

error_rate = 625
root_error = math.sqrt(error_rate)
print(f"Root Margin of Error: {root_error} LRD.")
# Out:
# Root Margin of Error: 25.0 LRD.

# %% [markdown]
# Method vs. Attributes in Practice

# %%
import pandas as pd

data = pd.DataFrame({
  "Owner": ["Ma Musu", "Sia"],
  "Revenue": [5000, 7000]
})

#ATTRIBUTE (no parentheses)
print(f"Data Grid Shape: {data. shape}")     #(2, 2)

#METHOD (parentheses)
print("First row:")
print(data.head(1))
# Out:
# Data Grid Shape: (2, 2)
# First row:
#      Owner  Revenue
# 0  Ma Musu     5000

# %% [markdown]
# Home Assignment 2

# %% [markdown]
# Question 1: Type Conversion(The Nimba Truck Report)
#
# A. Script to convert and calculate total cost

# %%
transport_cost = "750" # text data from driver
car_loader_fee = 250

#Convert text to integer and add fee
total_delivery_cost = int(transport_cost) + car_loader_fee

# %% [markdown]
# Explanation: int(transport_cost) converts the string "750" into the integer 750 so python can do math with it. Without this, you'd get an error because you can't add a string and an integer.

# %% [markdown]
# B.f-string report

# %%
print(f"Ma Christiana, your final shipping cost is: {total_delivery_cost} LRD.")
# Out:
# Ma Christiana, your final shipping cost is: 1000 LRD.

# %% [markdown]
# Question 2: Lists & Matrices(Packing the Shipping Crate)

# %% [markdown]
# A. Explanation
# A flat list like [45, 12, 88]is 1D. Machine Learning models expect input X as a 2D matrix/table with rows and columns, like a spreadsheet. Think of it like a delivery truck: it needs items packed in a crate with defined rows and columns, not loose on the truck bed. The model needs the shape (n_samples, n_features).

# %% [markdown]
# B. Pack into 2D matrix

# %%
loose_stock = [45, 12, 88]
shipping_crate = [[45, 12, 88]] # double brackets make it 2D with 1 row, 3 columns

# %% [markdown]
# Question 3: Dictionaries(Tuning the Motorbike Engine)

# %% [markdown]
# A. Create dictionary

# %%
yield_model_configs = {
    "engine_type": "Decision Tree",
    "max_depth_layers": 15,
    "strict_mode": True
}

# %% [markdown]
# B. f-string to print max depth

# %%
print(f"System check: Tuning engine depth to {yield_model_configs['max_depth_layers']}")
# Out:
# System check: Tuning engine depth to 15

# %% [markdown]
# Question 4: Methods vs. Attributes(The Commercial Transport Truck)

# %% [markdown]
# A. gobachop_data.shape vs gobachop_data.shape()
# Use gobachop_data.shape without()

# %% [markdown]
# Exlplanation using Delivery Truck Analogy:
#
#
# *   An attribute like .shape is a description of the truck-it tells you how many rows and columns exist right now. You just read it.
# *   A method like .shape() would be an action the truck performs. Since .shape is an attribute, adding () causes an error: TypeError: 'tuple' object is not callable.

# %% [markdown]
# B. Command to get top row

# %%
gobachop_data.head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2608/1971768527.py in <cell line: 0>()
# ----> 1 gobachop_data . head(1)
#
# NameError: name 'gobachop_data' is not defined
